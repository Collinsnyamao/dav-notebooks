# %%
import pandas as pd
import numpy as np

# %%
netflix_df = pd.read_csv('./data/netflix_titles.csv')
monster_df = pd.read_csv('./data/monster_job_data.csv')

# %%
monster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22007 entries, 0 to 22006
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          22007 non-null  object
#  1   country_code     22007 non-null  object
#  2   date_added       122 non-null    object
#  3   has_expired      22007 non-null  object
#  4   job_board        22007 non-null  object
#  5   job_description  22007 non-null  object
#  6   job_title        22007 non-null  object
#  7   job_type         20379 non-null  object
#  8   location         22007 non-null  object
#  9   organization     15133 non-null  object
#  10  page_url         22007 non-null  object
#  11  salary           3446 non-null   object
#  12  sector           16813 non-null  object
#  13  uniq_id          22007 non-null  object
# dtypes: object(14)
# memory usage: 2.4+ MB

# %%
monster_df.columns
# Out:
# Index(['country', 'country_code', 'date_added', 'has_expired', 'job_board',
#        'job_description', 'job_title', 'job_type', 'location', 'organization',
#        'page_url', 'salary', 'sector', 'uniq_id'],
#       dtype='object')

# %%
monster_df[['country_code', 'country']].iloc[0]
# Out:
# country_code                          US
# country         United States of America
# Name: 0, dtype: object

# %%
monster_df.iloc[0:3, 0:6]
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
#
#           job_board                                    job_description
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 2  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...

# %%
monster_df.loc[monster_df['job_type'] == 'Full Time']
# Out:
#                         country country_code date_added has_expired  \
# 2      United States of America           US        NaN          No
# 4      United States of America           US        NaN          No
# 17     United States of America           US        NaN          No
# 19     United States of America           US        NaN          No
# 20     United States of America           US        NaN          No
# ...                         ...          ...        ...         ...
# 21995  United States of America           US        NaN          No
# 22002  United States of America           US        NaN          No
# 22003  United States of America           US        NaN          No
# 22004  United States of America           US        NaN          No
# 22006  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# ...

# %%
monster_df.loc[monster_df['job_type'] == 'Full Time', ['country_code','country', 'job_type']]
# Out:
#       country_code                   country   job_type
# 2               US  United States of America  Full Time
# 4               US  United States of America  Full Time
# 17              US  United States of America  Full Time
# 19              US  United States of America  Full Time
# 20              US  United States of America  Full Time
# ...            ...                       ...        ...
# 21995           US  United States of America  Full Time
# 22002           US  United States of America  Full Time
# 22003           US  United States of America  Full Time
# 22004           US  United States of America  Full Time
# 22006           US  United States of America  Full Time
#
# [6757 rows x 3 columns]

# %%
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix_df.loc[(netflix_df['type'] == 'TV Show') & (netflix_df['release_year'] >= 2019), ['title', 'director', 'rating']]
# Out:
#                                           title         director rating
# 1                                 Blood & Water              NaN  TV-MA
# 2                                     Ganglands  Julien Leclercq  TV-MA
# 3                         Jailbirds New Orleans              NaN  TV-MA
# 4                                  Kota Factory              NaN  TV-MA
# 5                                 Midnight Mass    Mike Flanagan  TV-MA
# ...                                         ...              ...    ...
# 8125                                Super Wings              NaN   TV-Y
# 8132  Surviving R. Kelly Part II: The Reckoning              NaN  TV-MA
# 8173                                  Thackeray              NaN  TV-MA
# 8376                       The Kindness Diaries              NaN  TV-PG
# 8437                     The Netflix Afterparty              NaN  TV-MA
#
# [1148 rows x 3 columns]
