# %%
import pandas as pd

# %%
cat_data = pd.read_csv('./data/cat_data.csv')
cat_data
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0     34.0  Female         86.7        1.86     174    152.0         74.0
# 1     26.0  Female         84.7        1.83     166    156.0         73.0
# 2     22.0    Male         64.8        1.85     187    166.0         64.0
# 3     54.0  Female         75.3        1.82     187    169.0         58.0
# 4     34.0  Female         52.8        1.74     177    169.0         66.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1795  54.0    Male         88.5        2.00     173    134.0         58.0
# 1796  52.0    Male         84.3        1.69     164    169.0         54.0
# 1797  47.0    Male         70.1        1.84     188    129.0         67.0
# 1798  35.0    Male         49.3        1.71     180    152.0         73.0
# 1799  40.0    Male         79.5        1.92     184    156.0         52.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
#cat_data.info()

numerical_cols = cat_data.select_dtypes(include=['float64']).columns.tolist()
numerical_cols
# Out:
# ['Age',
#  'Weight (kg)',
#  'Height (m)',
#  'Avg_BPM',
#  'Resting_BPM',
#  'Session_Duration (hours)',
#  'Calories_Burned',
#  'Fat_Percentage',
#  'Water_Intake (liters)',
#  'Workout_Frequency (days/week)',
#  'Experience_Level',
#  'BMI']

# %%
categorical_cols = cat_data.select_dtypes(include=['object']).columns.tolist()
categorical_cols
# Out:
# ['Gender', 'Max_BPM', 'Workout_Type']

# %%
cat_data.describe()
# Out:
#                Age  Weight (kg)   Height (m)      Avg_BPM  Resting_BPM  \
# count  1790.000000  1778.000000  1774.000000  1770.000000  1781.000000
# mean     34.475419    67.606637     1.739233   146.259322    63.951151
# std      12.315728    19.861408     0.123892    15.219516     7.936502
# min      18.000000    40.000000     1.500000   120.000000    50.000000
# 25%      23.000000    52.300000     1.650000   133.250000    57.000000
# 50%      33.000000    65.300000     1.730000   146.000000    65.000000
# 75%      45.000000    80.100000     1.820000   160.000000    72.000000
# max      59.000000   129.900000     2.000000   169.000000    74.000000
#
#        Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count               1777.000000      1777.000000     1784.000000
# mean                   1.391598      1033.698931       23.509361
# std                    0.372342       328.049662        5.865557
# min                    0.500000       303.000000       10.000000
# ...

# %%
cat_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1790 non-null   float64
#  1   Gender                         1729 non-null   object
#  2   Weight (kg)                    1778 non-null   float64
#  3   Height (m)                     1774 non-null   float64
#  4   Max_BPM                        1779 non-null   object
#  5   Avg_BPM                        1770 non-null   float64
#  6   Resting_BPM                    1781 non-null   float64
#  7   Session_Duration (hours)       1777 non-null   float64
#  8   Calories_Burned                1777 non-null   float64
#  9   Workout_Type                   1739 non-null   object
#  10  Fat_Percentage                 1784 non-null   float64
#  11  Water_Intake (liters)          1776 non-null   float64
# ...

# %%
cat_data[['Age', 'Gender', 'Workout_Type', 'Calories_Burned', 'BMI']]
# Out:
#        Age  Gender Workout_Type  Calories_Burned    BMI
# 0     34.0  Female     Strength            712.0  14.31
# 1     26.0  Female     Strength            833.0  33.49
# 2     22.0    Male       Cardio           1678.0  12.73
# 3     54.0  Female       Cardio            628.0  20.37
# 4     34.0  Female     Strength           1286.0  20.83
# ...    ...     ...          ...              ...    ...
# 1795  54.0    Male         HIIT           1388.0  36.73
# 1796  52.0    Male         HIIT           1367.0  15.11
# 1797  47.0    Male     Strength           1261.0  17.99
# 1798  35.0    Male       Cardio            956.0  12.65
# 1799  40.0    Male     Strength           1178.0  23.51
#
# [1800 rows x 5 columns]

# %%
cat_data.loc[cat_data['Workout_Type'] == 'Cardio']
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 2     22.0    Male         64.8        1.85     187    166.0         64.0
# 3     54.0  Female         75.3        1.82     187    169.0         58.0
# 6     44.0  Female         46.5        1.81     191    142.0         74.0
# 14    19.0  Female         71.7        1.91     197    148.0         74.0
# 17    39.0  Female         71.3        1.77     171    124.0         74.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1777  18.0    Male         62.7        1.87     184    141.0         59.0
# 1784  51.0    Male         80.8        2.00     167    129.0         55.0
# 1786  18.0    Male         42.3        1.64     198    169.0         65.0
# 1793  20.0    Male         40.0        1.81     176    138.0         66.0
# 1798  35.0    Male         49.3        1.71     180    152.0         73.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
def get_unique_workouts():
   unique_workouts = (cat_data['Workout_Type']
                     .dropna()
                     .str.strip()
                     .str.title()
                     .unique())

   for workout in sorted(unique_workouts):
       print(f"  - {workout}")

   return unique_workouts
unique_workouts = get_unique_workouts()
# Out:
#   - Cardio
#   - Hiit
#   - Strength
#   - Yoga
#   - \Nstrength
#   - \Tcardio
#   - \Tyoga

# %%
cat_data.columns
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
new_df = cat_data.loc[(cat_data['Gender'] == 'Female') & (cat_data['BMI'] > 25) & (cat_data['Workout_Frequency (days/week)'] > 3)]

new_df
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 1     26.0  Female         84.7        1.83     166    156.0         73.0
# 32    44.0  Female         45.0        1.53     199    158.0         50.0
# 54    36.0  Female         40.0        1.71     178    169.0         69.0
# 66    33.0  Female         76.3        1.95     188    125.0         72.0
# 100   30.0  Female         96.3        2.00     173    136.0         74.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1700  58.0  Female         73.3        1.69     180    156.0         72.0
# 1717  33.0  Female         99.6        1.72     164    169.0         70.0
# 1731  20.0  Female         86.0        1.69     183    136.0         58.0
# 1752  49.0  Female         59.2        1.55     185    169.0         63.0
# 1755  18.0  Female         68.1        1.66     160    120.0         65.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
criteria = cat_data.loc[(cat_data['BMI'] > 30) & (cat_data['Fat_Percentage'] > 25)]

len(criteria)
# Out:
# 60
